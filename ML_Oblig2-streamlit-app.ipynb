# %%
#pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.2.0-py2.py3-none-any.whl (9.1 MB)
# Requirement already satisfied: packaging in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from streamlit) (21.3)
# Collecting pyarrow
#   Downloading pyarrow-6.0.1-cp38-cp38-win_amd64.whl (15.5 MB)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from streamlit) (3.19.1)
# Collecting base58
# Note: you may need to restart the kernel to use updated packages.  Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from streamlit) (1.3.4)
# Requirement already satisfied: tornado>=5.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from streamlit) (3.1.24)
# Collecting click<8.0,>=7.0
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: python-dateutil in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from streamlit) (2.8.1)
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Collecting astor
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting altair>=3.2.0
#   Downloading altair-4.1.0-py3-none-any.whl (727 kB)
# Collecting watchdog
#   Downloading watchdog-2.1.6-py3-none-win_amd64.whl (76 kB)
# Collecting cachetools>=4.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting tzlocal
#   Downloading tzlocal-4.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: attrs in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from streamlit) (21.2.0)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
# Collecting pympler>=0.9
#   Downloading Pympler-0.9.tar.gz (178 kB)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from streamlit) (2.26.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from streamlit) (8.4.0)
# Requirement already satisfied: numpy in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from streamlit) (1.19.5)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
# Requirement already satisfied: jinja2 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from altair>=3.2.0->streamlit) (3.0.3)
# Requirement already satisfied: entrypoints in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from altair>=3.2.0->streamlit) (0.3)
# Collecting toolz
#   Downloading toolz-0.11.2-py3-none-any.whl (55 kB)
#
# Requirement already satisfied: jsonschema in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from altair>=3.2.0->streamlit) (4.2.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from gitpython!=3.1.19->streamlit) (4.0.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from pandas>=0.21.0->streamlit) (2021.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (7.6.5)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.0.5)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.3.4)
# Requirement already satisfied: jupyter-client in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (6.1.7)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.18.1)
# Requirement already satisfied: pygments in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.8)
# Requirement already satisfied: setuptools>=18.5 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (58.0.4)
# Requirement already satisfied: backcall in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: colorama in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: decorator in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.4.2)
# Requirement already satisfied: pickleshare in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.18.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: jupyter-core in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.6.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit) (5.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from importlib-resources>=1.4.0->jsonschema->altair>=3.2.0->streamlit) (3.6.0)
# Requirement already satisfied: wcwidth in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from python-dateutil->streamlit) (1.15.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.4.6)
# Requirement already satisfied: argon2-cffi in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (21.1.0)
# Requirement already satisfied: nbconvert in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.3.0)
# Requirement already satisfied: prometheus-client in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.12.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.12.1)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (19.0.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (227)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.1.6)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.21)
# Requirement already satisfied: bleach in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.9)
# Requirement already satisfied: testpath in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: webencodings in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from packaging->streamlit) (3.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from requests->streamlit) (2020.6.20)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from requests->streamlit) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from requests->streamlit) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\spydk\anaconda3\envs\py38\lib\site-packages (from requests->streamlit) (1.26.7)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting tzdata
#   Downloading tzdata-2021.5-py2.py3-none-any.whl (339 kB)
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-win_amd64.whl (38 kB)
# Building wheels for collected packages: pympler, blinker
#   Building wheel for pympler (setup.py): started
#   Building wheel for pympler (setup.py): finished with status 'done'
#   Created wheel for pympler: filename=Pympler-0.9-py3-none-any.whl size=164824 sha256=c2f5ab28556f0fddbd94b9e48b3df3d866dba68ac6e1bece85b049e6766f5361
#   Stored in directory: c:\users\spydk\appdata\local\pip\cache\wheels\24\6f\0b\da9f81234859a8741aaea3afcc6ae2daf0efb67e7ff2d3686c
#   Building wheel for blinker (setup.py): started
#   Building wheel for blinker (setup.py): finished with status 'done'
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13478 sha256=78d1703fd5b5d4e2c31a090659d9a0d71283eaa9acc770a7e0edd123d4ba4815
#   Stored in directory: c:\users\spydk\appdata\local\pip\cache\wheels\b7\a5\68\fe632054a5eadd531c7a49d740c50eb6adfbeca822b4eab8d4
# Successfully built pympler blinker
# Installing collected packages: tzdata, backports.zoneinfo, toolz, pytz-deprecation-shim, watchdog, validators, tzlocal, toml, pympler, pydeck, pyarrow, click, cachetools, blinker, base58, astor, altair, streamlit
#   Attempting uninstall: click
#     Found existing installation: click 8.0.3
#     Uninstalling click-8.0.3:
#       Successfully uninstalled click-8.0.3
# Successfully installed altair-4.1.0 astor-0.8.1 backports.zoneinfo-0.2.1 base58-2.1.1 blinker-1.4 cachetools-4.2.4 click-7.1.2 pyarrow-6.0.1 pydeck-0.7.1 pympler-0.9 pytz-deprecation-shim-0.1.0.post0 streamlit-1.2.0 toml-0.10.2 toolz-0.11.2 tzdata-2021.5 tzlocal-4.1 validators-0.18.2 watchdog-2.1.6

# %%
from pycaret.regression import load_model, predict_model 
import pandas as pd 
import numpy as np
import streamlit as st
from PIL import Image
import os

# %%
class StreamlitApp:
    
    def __init__(self):
        self.model = load_model('final_model') 
        self.save_fn = 'path.csv'     
        
    def predict(self, input_data): 
        return predict_model(self.model, data=input_data)
    
    def store_prediction(self, output_df): 
        if os.path.exists(self.save_fn):
            save_df = pd.read_csv(self.save_fn)
            save_df = save_df.append(output_df, ignore_index=True)
            save_df.to_csv(self.save_fn, index=False)
            
        else: 
            output_df.to_csv(self.save_fn, index=False)  
    
    def preprocess(self, data):
   # Preprocess method insipred by code from predict.py from the Flask-tutorial hospitalapp

   # This method makes sure all features are defined going into the model
    
        null = None
        
        # Setting default values for some of the features, while letting the models imputation method deal with the other potentially 
        # missing values (that are  not retrieved from user)
        feature_values = {
            'Id':null, 'MSSubClass': null, 'MSZoning': null, 'LotFrontage':null, 'LotArea':null, 'Street': null,
       'Alley': null, 'LotShape': null, 'LandContour':null, 'Utilities':null, 'LotConfig':null,
       'LandSlope':null, 'Neighborhood':null, 'Condition1':null, 'Condition2':null, 'BldgType':null,
       'HouseStyle':null, 'OverallQual':null, 'OverallCond':null, 'YearBuilt':null, 'YearRemodAdd':null,
       'RoofStyle':null, 'RoofMatl':null, 'Exterior1st':null, 'Exterior2nd':null, 'MasVnrType':null,
       'MasVnrArea':0, 'ExterQual':null, 'ExterCond':null, 'Foundation':null, 'BsmtQual':null,
       'BsmtCond':null, 'BsmtExposure':null, 'BsmtFinType1':null, 'BsmtFinSF1':0,
       'BsmtFinType2':null, 'BsmtFinSF2':0, 'BsmtUnfSF':0, 'TotalBsmtSF':0, 'Heating':null,
       'HeatingQC':null, 'CentralAir':null, 'Electrical':null, '1stFlrSF':0, '2ndFlrSF':0,
       'LowQualFinSF':0, 'GrLivArea':null, 'BsmtFullBath':0, 'BsmtHalfBath':0, 'FullBath':1,
       'HalfBath':0, 'BedroomAbvGr':null, 'KitchenAbvGr':1, 'KitchenQual':null,
       'TotRmsAbvGrd':5, 'Functional':null, 'Fireplaces':0, 'FireplaceQu':null, 'GarageType':null,
       'GarageYrBlt':null, 'GarageFinish':null, 'GarageCars':null, 'GarageArea':0, 'GarageQual':null,
       'GarageCond':null, 'PavedDrive':null, 'WoodDeckSF':0, 'OpenPorchSF':0,
       'EnclosedPorch':0, '3SsnPorch':0, 'ScreenPorch':0, 'PoolArea':0, 'PoolQC':null,
       'Fence':null, 'MiscFeature':null, 'MiscVal':0, 'MoSold':null, 'YrSold':null, 'SaleType':null,
       'SaleCondition':null
        }

        # Parse the form inputs and return the features updated with values entered.
        for key in [k for k in data.keys() if k in feature_values.keys()]:
            feature_values[key] = data[key]

        return feature_values
    
    def run(self):
        #image = Image.open('../assets/human-heart.jpg')
        #st.image(image, use_column_width=False)
    
    
        add_selectbox = st.sidebar.selectbox('How would you like to predict?', ('Online', 'Batch')) #bruke batch for aa predikere paa alle bildene. 
        st.sidebar.info('This app is created to predict house price' )
        st.sidebar.success('DAT158')
        st.title('House price prediction')
        
       
        if add_selectbox == 'Online': 
            
            

            
            output=''
            input_dict = self.preprocess(user_input)
            input_df = pd.DataFrame(input_dict, index=[0])
        
            if st.button('Predict'): 
                output = self.predict(input_df)
                self.store_prediction(output)
                
                output = output['Label'][0].round(2)
                
            
            st.success('Predicted price: {}'.format(output))
            
        if add_selectbox == 'Batch': 
            fn = st.file_uploader("Upload csv file for predictions") #st.file_uploader('Upload csv file for predictions, type=["csv"]')
            if fn is not None: 
                input_df = pd.read_csv(fn)
                predictions = self.predict(input_df)
                st.write(predictions)
            
sa = StreamlitApp()
sa.run()
# Out:
# 2021-11-28 23:50:54.339 INFO    logs: Initializing load_model()
# 2021-11-28 23:50:54.346 INFO    logs: load_model(model_name=final_model, platform=None, authentication=None, verbose=True)
# Transformation Pipeline and Model Successfully Loaded
# 2021-11-28 23:50:54.968
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\spydk\anaconda3\envs\py38\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6e7133430c71> in <module>
#      89
#      90 sa = StreamlitApp()
# ---> 91 sa.run()
#
# <ipython-input-3-6e7133430c71> in run(self)
#      69
#      70             output=''
# ---> 71             input_dict = self.preprocess(user_input)
#      72             input_df = pd.DataFrame(input_dict, index=[0])
#      73
#
# NameError: name 'user_input' is not defined

# %%
# !jupyter nbconvert --to script ML_Oblig2-streamlit-app.ipynb
# Out:
# [NbConvertApp] Converting notebook ML_Oblig2-streamlit-app.ipynb to script
# [NbConvertApp] Writing 4566 bytes to ML_Oblig2-streamlit-app.py
